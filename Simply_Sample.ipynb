# %%
# %matplotlib inline
from pysumma.Simulation import Simulation

# %%
S = Simulation('/home/hydro/Downloads/summaTestCases_2.x/settings/wrrPaperTestCases/figure07/summa_fileManager_riparianAspenSimpleResistance.txt')

# %%
S.executable = "/home/hydro/Downloads/summa-master/bin/summa.exe"

# %%
S.decision_obj.stomResist.options
# Out:
# ['BallBerry', 'Jarvis', 'simpleResistance']

# %%
S.decision_obj.stomResist.value
# Out:
# 'BallBerry'

# %%
results_simp = S.execute("simp")

# %%
results_simp['scalarGroundEvaporation'].plot()
# Out:
# /home/hydro/miniconda3/lib/python3.6/site-packages/xarray/plot/utils.py:51: FutureWarning: 'pandas.tseries.converter.register' has been moved and renamed to 'pandas.plotting.register_matplotlib_converters'.
#   converter.register()

# %%
S.decision_obj.stomResist.value = "BallBerry"

# %%
results_bb = S.execute("BallBerry_tst")
